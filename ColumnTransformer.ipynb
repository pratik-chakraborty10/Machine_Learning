# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-chakraborty10/Machine_Learning/blob/main/ColumnTransformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('/content/covid_toy.csv')

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                test_size=0.2)

# %%
X_train.head()
# Out:
#     age  gender  fever   cough       city
# 26   19  Female  100.0    Mild    Kolkata
# 28   16    Male  104.0    Mild    Kolkata
# 98    5  Female   98.0  Strong     Mumbai
# 47   18  Female  104.0    Mild  Bangalore
# 61   81  Female   98.0  Strong     Mumbai

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse=False,drop='first'),['gender','city'])
],remainder='passthrough')

# %%
transformer.fit_transform(X_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# array([[100.        ,   0.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,  19.        ],
#        [104.        ,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  16.        ],
#        [ 98.        ,   1.        ,   0.        ,   0.        ,
#           0.        ,   1.        ,   5.        ],
#        [104.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,  18.        ],
#        [ 98.        ,   1.        ,   0.        ,   0.        ,
#           0.        ,   1.        ,  81.        ],
#        [ 98.        ,   1.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,  40.        ],
# ...

# %%
transformer.fit_transform(X_train).shape
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# (80, 7)

# %%
transformer.transform(X_test)
# Out:
# array([[103.        ,   0.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,  73.        ],
#        [104.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   1.        ,  42.        ],
#        [ 99.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  65.        ],
#        [ 99.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  72.        ],
#        [100.        ,   1.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,  11.        ],
#        [101.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   1.        ,  65.        ],
#        [100.        ,   0.        ,   1.        ,   1.        ,
#           0.        ,   0.        ,  27.        ],
#        [ 98.        ,   0.        ,   1.        ,   1.        ,
#           0.        ,   0.        ,  83.        ],
# ...

# %%
transformer.transform(X_test).shape
# Out:
# (20, 7)
