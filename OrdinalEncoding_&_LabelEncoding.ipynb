# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-chakraborty10/Machine_Learning/blob/main/OrdinalEncoding_%26_LabelEncoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 25   57  Female     Good    School        No
# 28   48    Male     Poor    School        No
# 5    31  Female  Average    School       Yes
# 14   15    Male     Poor        PG       Yes
# 26   53  Female     Poor        PG        No

# %%
df=df.iloc[:,2:]

# %%
df.head(3)
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,0:2],df.iloc[:,:-1],test_size=0.2)

# %%
X_train
# Out:
#      review education
# 27     Poor        PG
# 36     Good        UG
# 37  Average        PG
# 34  Average    School
# 48     Good        UG
# 38     Good    School
# 24  Average        PG
# 40     Good    School
# 25     Good    School
# 6      Good    School
# 49     Good        UG
# 29  Average        UG
# 15     Poor        UG
# 21  Average        PG
# 11     Good        UG
# 0   Average    School
# 8   Average        UG
# 20  Average    School
# 4   Average        UG
# 7      Poor    School
# 13  Average    School
# 46     Poor        PG
# 41     Good        PG
# 45     Poor        PG
# 5   Average    School
# 16     Poor        UG
# 22     Poor        PG
# 9      Good        UG
# 3      Good        PG
# 10     Good        UG
# 18     Good    School
# 43     Poor        PG
# 26     Poor        PG
# 30  Average        UG
# 31     Poor    School
# 35     Poor    School
# 2      Good        PG
# 19     Poor        PG
# 28     Poor    School
# 23     Good    School

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit_transform(X_train)
# Out:
# array([[0., 2.],
#        [2., 1.],
#        [1., 2.],
#        [1., 0.],
#        [2., 1.],
#        [2., 0.],
#        [1., 2.],
#        [2., 0.],
#        [2., 0.],
#        [2., 0.],
#        [2., 1.],
#        [1., 1.],
#        [0., 1.],
#        [1., 2.],
#        [2., 1.],
#        [1., 0.],
#        [1., 1.],
#        [1., 0.],
#        [1., 1.],
#        [0., 0.],
#        [1., 0.],
#        [0., 2.],
#        [2., 2.],
#        [0., 2.],
#        [1., 0.],
#        [0., 1.],
#        [0., 2.],
#        [2., 1.],
#        [2., 2.],
#        [2., 1.],
#        [2., 0.],
#        [0., 2.],
#        [0., 2.],
#        [1., 1.],
#        [0., 0.],
#        [0., 0.],
#        [2., 2.],
#        [0., 2.],
#        [0., 0.],
#        [2., 0.]])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(y_train)
y_train = le.transform(y_train)
y_test = le.transform(y_test)
